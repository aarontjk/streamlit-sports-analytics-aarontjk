# %%
import pandas as pd

# %%
players = pd.read_csv("../raw_data/FM 2023.csv")

# %%
players
# Out:
#                     Name  Position  Age   ca   pa     Nationality  \
# 0        Kevin De Bruyne  M/AM RLC   31  189  189         Belgium
# 1          Kylian Mbappé   AM/S RL   23  188  197          France
# 2     Robert Lewandowski         S   33  186  190          Poland
# 3         Erling Haaland         S   22  185  195  Norway,England
# 4          Mohamed Salah   AM/S RL   30  185  187           Egypt
# ...                  ...       ...  ...  ...  ...             ...
# 8447          Joe Ashton       D L   16   45  135         England
# 8448          River Ries         S   17   45  135         Germany
# 8449      Halilcan Doğan       D C   23   45  -75          Turkey
# 8450        Adijat Sefer         S   17   45  135         Germany
# 8451         Linus Urban         S   17   45  135         Germany
#
#                             Club  Corners  Crossing  Dribbling  ...  \
# 0                Manchester City       14        19         15  ...
# ...

# %%
clubs_df = players[['Club']].dropna(axis=0)

# %%
clubs_df
# Out:
#                             Club
# 0                Manchester City
# 1            Paris Saint-Germain
# 2                      Barcelona
# 3                Manchester City
# 4                      Liverpool
# ...                          ...
# 8447                     Burnley
# 8448               Karlsruher SC
# 8449  Osmaniyespor Futbol Kulübü
# 8450              TSG Hoffenheim
# 8451            SV Werder Bremen
#
# [8345 rows x 1 columns]

# %%
clubs = list(clubs_df['Club'].unique())

# %%
clubs.sort()

# %%
clubs
# Out:
# ['1. FC Heidenheim 1846',
#  '1. FC Kaiserslautern',
#  '1. FC Köln',
#  '1. FC Magdeburg',
#  '1. FC Nürnberg',
#  '1. FC Saarbrücken',
#  '1. FC Union Berlin',
#  '1. FSV Mainz 05',
#  'A. Bilbao',
#  'A. Madrid',
#  'A.M.S. y D. Atlético de Rafaela',
#  'AC Ajaccio',
#  'AC Milan',
#  'ACF Fiorentina',
#  'ADO Den Haag',
#  'AE Kition Larnakas',
#  'AE Limassol',
#  'AEK Athens',
#  'AFC Ajax',
#  'AFC Bournemouth',
#  'AFC Wimbledon',
#  'AIK',
#  'AJ Auxerre',
#  'AMG',
#  'APOEL Nicosia',
#  'APS Atromitos Athens',
#  'AS Académie Génération Foot',
#  'AS Aris Salonika',
#  'AS Monaco',
#  'AS Nancy Lorraine',
#  'AS PAOK Salonika',
#  'AS Saint-Etienne',
#  'AS Trencin',
#  'ASEC Mimosas',
#  'ATG',
#  'ATM',
#  'ATP',
#  'AVA',
#  'AZ Alkmaar',
#  'Aalborg Boldspilklub',
#  'Aarhus Gymnastik Forening',
#  'Aberdeen',
#  'Abha Club',
#  'Abuko Falcons Football Club',
#  'Académico de Viseu Futebol Clube',
#  'Académie Foot Darou Salam',
#  'Académie Mohammed VI de Football',
# ...

# %%
players.head(2)
# Out:
#               Name  Position  Age   ca   pa Nationality                 Club  \
# 0  Kevin De Bruyne  M/AM RLC   31  189  189     Belgium      Manchester City
# 1    Kylian Mbappé   AM/S RL   23  188  197      France  Paris Saint-Germain
#
#    Corners  Crossing  Dribbling  ...  World reputation               Race  \
# 0       14        19         15  ...              9400  Northern_European
# 1       13        13         18  ...              9248  African_Caribbean
#
#    RCA  Colour of skin  Date of birth  Number of national team appearances  \
# 0  181               4      1991/6/28                                   91
# 1  172              13     1998/12/20                                   57
#
#    Goals scored for the national team     Salary  Rental club       UID
# 0                                  24   394372.0          NaN  18004457
# 1                                  27  1035616.0          NaN  85139014
#
# [2 rows x 98 columns]

# %%
home_team = 'Manchester City'

# %%
home_players = players.query(f"Club == '{home_team}'")

# %%
list(home_players['Name'])
# Out:
# ['Kevin De Bruyne',
#  'Erling Haaland',
#  'Bernardo Silva',
#  'Ederson',
#  'Rodri',
#  'Rúben Dias',
#  'Aymeric Laporte',
#  'João Cancelo',
#  'Jack Grealish',
#  'İlkay Gündogan',
#  'Kyle Walker',
#  'Phil Foden',
#  'John Stones',
#  'Riyad Mahrez',
#  'Manuel Akanji',
#  'Nathan Aké',
#  'Kalvin Phillips',
#  'Julián Álvarez',
#  'Zack Steffen',
#  'Yangel Herrera',
#  'Cole Palmer',
#  'Sergio Gómez',
#  'Yan Couto',
#  'Stefan Ortega',
#  'Nahuel Bustos',
#  'Taylor Harwood-Bellis',
#  'Filip Stevanović',
#  'Tommy Doyle',
#  'Issa Kaboré',
#  'Liam Delap',
#  'Morgan Rogers',
#  'Kayky',
#  'James Trafford',
#  'James McAtee',
#  'Rico Lewis',
#  'Darío Sarmiento',
#  'Josh Wilson-Esbrand',
#  'Diego Rosa',
#  'Oscar Bobb',
#  'Callum Doyle',
#  'Finley Burns',
#  'Luke Mbete',
#  'Dire Mebude',
#  'Micah Hamilton',
#  'Carlos Borges',
#  'Mikki van Sas',
#  'Josh Adam',
#  'Tomas Galvez',
#  'Daniel Ogwuru',
#  'Joel Ndala',
#  'Kane Taylor',
#  'Alfie Harrison',
# ...
